# %% [markdown]
# # Genshin Impact Knowledge Graph
# # Submitted By: K16-Sarim-Raffay-Zaraar

# %%
import pandas as pd
from rdflib import Graph, Literal, RDF, URIRef, Namespace, RDFS, OWL, FOAF
from rdflib.namespace import FOAF , XSD 
import urllib.parse
import numpy as np
import numpy as np

# %% [markdown]
# # Base Ontology

# %%
g = Graph()
g = g.parse('baseProject.rdf', format='application/rdf+xml')

gOnto = Namespace('http://www.genshin.org/ontology/')
gRes = Namespace('http://www.genshin.org/resource/')
foaf = Namespace("http://xmlns.com/foaf/0.1/")
wd = Namespace("http://www.wikidata.org/entity/")

g.bind('genshinOntology', gOnto)
g.bind('genshinResource', gRes)
g.bind('foaf', foaf)
g.bind('wd', wd)

print(g.serialize(format="turtle"))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinOntology:OtherMaterial a owl:Class ;
#     rdfs:comment "Any material that isnt a weapon upgrade material nor a character upgrade material" ;
#     rdfs:subClassOf genshinOntology:Material ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Material [ a owl:Class ;
#                         owl:complementOf [ a owl:Class ;
#                                 owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:WeaponUpgradeMaterial ) ] ] ) ] .
#
# genshinOntology:VisionHolder a owl:Class ;
#     rdfs:comment "Any character which has a vision (visions are basically elemental affinities given to characters)" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) ] .
#
# genshinOntology:WeaponHolder a owl:Class ;
#     rdfs:comment "Any character which weilds a weapon" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) ] .
#
# genshinOntology:canEasilyDefeat a owl:ObjectProperty ;
#     rdfs:comment "Inferred from SWRL rules. Only given to those characters which can easily defeat an enemy given that the enemy is weak to the character's element" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Enemy ;
#     owl:inverseOf genshinOntology:isEasilyDefeatedBy .
#
# genshinOntology:enemyWeakAgainst a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which is weak to a particular element. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Element .
#
# genshinOntology:isArchon a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value being true is a character is an archon" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:isEasilyDefeatedBy a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule. Pair all enemies which are easily defeated by a character" .
#
# genshinOntology:residesAt a owl:ObjectProperty ;
#     rdfs:comment "Any character that resides in a region" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Region .
#
# genshinOntology:weaponUsedBy a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule property. Pair all weapons which of a specific weapon type to characters that use that specific weapon type" .
#
# :element a swrl:Variable .
#
# genshinOntology:AnemoCharacter a owl:Class ;
#     rdfs:comment "A character which has an Anemo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Anemo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:CryoCharacter a owl:Class ;
#     rdfs:comment "A character which has a Cryo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Cryo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual .
#
# genshinOntology:DendroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Dendro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Dendro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:ElectroCharacter a owl:Class ;
#     rdfs:comment "A character which has an Electro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Electro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:GeoCharacter a owl:Class ;
#     rdfs:comment "A character which has a Geo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Geo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:HydroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Hydro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Hydro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:PyroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Pyro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Pyro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Region a owl:Class ;
#     rdfs:comment "Countries where characters usually reside in" .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# :character a swrl:Variable .
#
# :enemy a swrl:Variable .
#
# genshinOntology:Boss a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Very tough enemies (They even have a health bar shown on the screen)" ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Boss ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:BowUser a owl:Class ;
#     rdfs:comment "A character which uses a Bow" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:CatalystUser a owl:Class ;
#     rdfs:comment "A character which uses a Catalyst" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:CharacterUpgradeMaterial a owl:Class ;
#     rdfs:comment "A material which is used to upgrade characters" ;
#     rdfs:subClassOf genshinOntology:Material .
#
# genshinOntology:ClaymoreUser a owl:Class ;
#     rdfs:comment "A character which uses a Claymore" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:Elite a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Elite ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:Normal a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Normal ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:PolearmUser a owl:Class ;
#     rdfs:comment "A character which uses a Polearm" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:Reaction a owl:Class ;
#     rdfs:comment "Reactions are well....reactions caused when two elements combine, creating a new effect. You need atleast two elements to react together to cause a reaction" ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "2"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:SwordUser a owl:Class ;
#     rdfs:comment "A character which uses a Sword" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:WeaponUpgradeMaterial a owl:Class ;
#     rdfs:comment "A material which is used to upgrade weapons" ;
#     rdfs:subClassOf genshinOntology:Material .
#
# genshinOntology:WeeklyBoss a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:WeeklyBoss ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:requiresElement a owl:ObjectProperty ;
#     rdfs:comment "Any reaciton which requires a specific element" .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual .
#
# genshinOntology:hasRole a owl:ObjectProperty ;
#     rdfs:comment "Any character that has a specific role. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Role .
#
# genshinOntology:isEnemyType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:EnemyType .
#
# genshinOntology:canWeildWeapon a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule property. Pair all characters which use a specific weapon type to weapons of that specific weapon type" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Weapon ;
#     owl:inverseOf genshinOntology:weaponUsedBy .
#
# genshinOntology:isWeaponType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponType .
#
# genshinOntology:usesWeaponType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:WeaponType .
#
# genshinOntology:EnemyType a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Role a owl:Class ;
#     rdfs:comment "Enumerated class of DPS, Healer, Shielder and Support. There are only 4 major roles a character usually has (you deduce this by looking at their kit overall in-depth). Many databases have already classified each character in a specific role they excel at" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:DPS genshinOntology:Healer genshinOntology:Shielder genshinOntology:Support ) ] .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:PlayableCharacter a owl:Class ;
#     rdfs:comment "Every playable character in genshin has a vision and has some preferred weapon they like using" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:VisionHolder genshinOntology:WeaponHolder ) ] .
#
# genshinOntology:WeaponType a owl:Class ;
#     rdfs:comment "Types for each Weapon (Bow, Catalyst, Claymore, Polearm and Sword)." ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:elementAlignment a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character having an element . It's made functional because a character cannot have more than 1 element. If they do, it should mean that the two element instances are the same individuals." ;
#     rdfs:range genshinOntology:Element .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %% [markdown]
# # Adding Reactions

# %%
df=pd.read_csv('./database/Reactions.csv',sep=",")
df.head()
# Out:
#    Element causesReaction
# 0     Pyro     Overloaded
# 1  Electro     Overloaded
# 2     Pyro           Melt
# 3     Cryo           Melt
# 4     Pyro       Vaporize

# %%
for index, row in df.iterrows():
    g.add((URIRef(gRes+row['Element']), URIRef(gOnto+row.index[1]), URIRef(gRes+row['causesReaction'])))
    g.add((URIRef(gRes+row['Element']), RDFS.label, Literal(row['Element'], datatype = XSD.string)))
    g.add((URIRef(gRes+row['causesReaction']), RDFS.label, Literal(row['causesReaction'], datatype = XSD.string)))
    
print(g.serialize(format='turtle'))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinOntology:OtherMaterial a owl:Class ;
#     rdfs:comment "Any material that isnt a weapon upgrade material nor a character upgrade material" ;
#     rdfs:subClassOf genshinOntology:Material ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Material [ a owl:Class ;
#                         owl:complementOf [ a owl:Class ;
#                                 owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:WeaponUpgradeMaterial ) ] ] ) ] .
#
# genshinOntology:VisionHolder a owl:Class ;
#     rdfs:comment "Any character which has a vision (visions are basically elemental affinities given to characters)" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) ] .
#
# genshinOntology:WeaponHolder a owl:Class ;
#     rdfs:comment "Any character which weilds a weapon" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) ] .
#
# genshinOntology:canEasilyDefeat a owl:ObjectProperty ;
#     rdfs:comment "Inferred from SWRL rules. Only given to those characters which can easily defeat an enemy given that the enemy is weak to the character's element" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Enemy ;
#     owl:inverseOf genshinOntology:isEasilyDefeatedBy .
#
# genshinOntology:enemyWeakAgainst a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which is weak to a particular element. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Element .
#
# genshinOntology:isArchon a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value being true is a character is an archon" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:isEasilyDefeatedBy a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule. Pair all enemies which are easily defeated by a character" .
#
# genshinOntology:residesAt a owl:ObjectProperty ;
#     rdfs:comment "Any character that resides in a region" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Region .
#
# genshinOntology:weaponUsedBy a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule property. Pair all weapons which of a specific weapon type to characters that use that specific weapon type" .
#
# :element a swrl:Variable .
#
# genshinOntology:AnemoCharacter a owl:Class ;
#     rdfs:comment "A character which has an Anemo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Anemo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:CryoCharacter a owl:Class ;
#     rdfs:comment "A character which has a Cryo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Cryo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual .
#
# genshinOntology:DendroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Dendro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Dendro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:ElectroCharacter a owl:Class ;
#     rdfs:comment "A character which has an Electro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Electro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:GeoCharacter a owl:Class ;
#     rdfs:comment "A character which has a Geo Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Geo ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:HydroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Hydro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Hydro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:PyroCharacter a owl:Class ;
#     rdfs:comment "A character which has a Pyro Vision" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinResource:Pyro ;
#                         owl:onProperty genshinOntology:elementAlignment ] ) ] .
#
# genshinOntology:Region a owl:Class ;
#     rdfs:comment "Countries where characters usually reside in" .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinResource:Burning rdfs:label "Burning"^^xsd:string .
#
# genshinResource:Electro-Charged rdfs:label "Electro-Charged"^^xsd:string .
#
# genshinResource:Frozen rdfs:label "Frozen"^^xsd:string .
#
# genshinResource:Melt rdfs:label "Melt"^^xsd:string .
#
# genshinResource:Overloaded rdfs:label "Overloaded"^^xsd:string .
#
# genshinResource:Quicken rdfs:label "Quicken"^^xsd:string .
#
# genshinResource:Superconduct rdfs:label "Superconduct"^^xsd:string .
#
# genshinResource:Vaporize rdfs:label "Vaporize"^^xsd:string .
#
# :character a swrl:Variable .
#
# :enemy a swrl:Variable .
#
# genshinOntology:Boss a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Very tough enemies (They even have a health bar shown on the screen)" ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Boss ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:BowUser a owl:Class ;
#     rdfs:comment "A character which uses a Bow" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:CatalystUser a owl:Class ;
#     rdfs:comment "A character which uses a Catalyst" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:CharacterUpgradeMaterial a owl:Class ;
#     rdfs:comment "A material which is used to upgrade characters" ;
#     rdfs:subClassOf genshinOntology:Material .
#
# genshinOntology:ClaymoreUser a owl:Class ;
#     rdfs:comment "A character which uses a Claymore" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:Elite a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Elite ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:Normal a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Normal ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:PolearmUser a owl:Class ;
#     rdfs:comment "A character which uses a Polearm" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:Reaction a owl:Class ;
#     rdfs:comment "Reactions are well....reactions caused when two elements combine, creating a new effect. You need atleast two elements to react together to cause a reaction" ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "2"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:SwordUser a owl:Class ;
#     rdfs:comment "A character which uses a Sword" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:usesWeaponType ] ) ] .
#
# genshinOntology:WeaponUpgradeMaterial a owl:Class ;
#     rdfs:comment "A material which is used to upgrade weapons" ;
#     rdfs:subClassOf genshinOntology:Material .
#
# genshinOntology:WeeklyBoss a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:WeeklyBoss ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinOntology:requiresElement a owl:ObjectProperty ;
#     rdfs:comment "Any reaciton which requires a specific element" .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Swirl .
#
# genshinResource:Burgeon rdfs:label "Burgeon"^^xsd:string .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Frozen,
#         genshinResource:Melt,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Hyperbloom,
#         genshinResource:Quicken .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Electro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Hyperbloom,
#         genshinResource:Overloaded,
#         genshinResource:Quicken,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Geo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Frozen,
#         genshinResource:Hyperbloom,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinResource:Hyperbloom rdfs:label "Hyperbloom"^^xsd:string .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Pyro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Crystallize,
#         genshinResource:Melt,
#         genshinResource:Overloaded,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:hasRole a owl:ObjectProperty ;
#     rdfs:comment "Any character that has a specific role. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Role .
#
# genshinOntology:isEnemyType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:EnemyType .
#
# genshinOntology:canWeildWeapon a owl:ObjectProperty ;
#     rdfs:comment "SWRL Rule property. Pair all characters which use a specific weapon type to weapons of that specific weapon type" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Weapon ;
#     owl:inverseOf genshinOntology:weaponUsedBy .
#
# genshinOntology:isWeaponType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponType .
#
# genshinOntology:usesWeaponType a owl:ObjectProperty ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:WeaponType .
#
# genshinResource:Crystallize rdfs:label "Crystallize"^^xsd:string .
#
# genshinResource:Swirl rdfs:label "Swirl"^^xsd:string .
#
# genshinOntology:EnemyType a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Role a owl:Class ;
#     rdfs:comment "Enumerated class of DPS, Healer, Shielder and Support. There are only 4 major roles a character usually has (you deduce this by looking at their kit overall in-depth). Many databases have already classified each character in a specific role they excel at" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:DPS genshinOntology:Healer genshinOntology:Shielder genshinOntology:Support ) ] .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:PlayableCharacter a owl:Class ;
#     rdfs:comment "Every playable character in genshin has a vision and has some preferred weapon they like using" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:VisionHolder genshinOntology:WeaponHolder ) ] .
#
# genshinOntology:WeaponType a owl:Class ;
#     rdfs:comment "Types for each Weapon (Bow, Catalyst, Claymore, Polearm and Sword)." ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:elementAlignment a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character having an element . It's made functional because a character cannot have more than 1 element. If they do, it should mean that the two element instances are the same individuals." ;
#     rdfs:range genshinOntology:Element .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %%
g.serialize(destination="afterAddingElements.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Adding Characters

# %%
df=pd.read_csv('./database/Characters.csv',sep=",")
df['character_name'] = df['character_name'].str.replace(' ', '_')
df['constellation'] = df['constellation'].str.replace(' ', '_')
df['birthday'] = pd.to_datetime(df['birthday'], format='%d/%m/%Y')
df['release_date'] = pd.to_datetime(df['release_date'], format='%m/%d/%Y')
df['ascension_boss'] = df['ascension_boss'].str.replace(' ', '_')
df['ascension'] = df['ascension'].str.replace(' ', '_')
df.head()
# Out:
#   character_name  rarity     region  vision weapon_type       constellation  \
# 0         Albedo       5  Mondstadt     Geo       Sword  Princeps_Cretaceus
# 1      Alhaitham       5     Sumeru  Dendro       Sword       Vultur_Volans
# 2           Aloy       5  Mondstadt    Cryo         Bow         Nora_Fortis
# 3          Amber       4  Mondstadt    Pyro         Bow               Lepus
# 4   Arataki_Itto       5    Inazuma     Geo    Claymore    Taurus_Iracundus
#
#     birthday     ascension_boss  limited         ascension     role  gender  \
# 0 2023-09-13      Basalt_Pillar     True     Geo_DMG_Bonus  Support    Male
# 1 2023-02-11     Pseudo-Stamens     True  Dendro_DMG_Bonus      DPS    Male
# 2 2023-04-04  Crystalline_Bloom     True    Cryo_DMG_Bonus  Support  Female
# 3 2023-08-10     Everflame_Seed    False               ATK  Support  Female
# 4 2023-06-01   Riftborn_Regalia     True         CRIT_Rate      DPS    Male
#
#    archon release_date
# 0   False   2020-09-28
# 1   False   2023-01-18
# 2   False   2021-09-01
# 3   False   2020-09-28
# 4   False   2021-12-14

# %%
for index, row in df.iterrows():
    name = URIRef(gRes+row['character_name'])
    constellation = URIRef(gRes+row['constellation'])
    characterMaterial = URIRef(gRes+row['ascension_boss'])
    role = URIRef(gOnto+row['role'])
    
    g.add((name, RDF.type, URIRef(gOnto + "Character")))    
    g.add((name, RDF.type, OWL.NamedIndividual))
    g.add((name, FOAF.name, Literal(row['character_name'])))
    g.add((name, RDFS.label, Literal(row['character_name'], datatype = XSD.string)))
    
    g.add((constellation, RDF.type, URIRef(gOnto + "Constellation")))
    g.add((constellation, RDF.type, OWL.NamedIndividual))
    g.add((constellation, RDFS.label, Literal(row['constellation'], datatype = XSD.string)))
    
    g.add((characterMaterial, RDF.type, URIRef(gOnto + "Material")))
    g.add((characterMaterial, RDF.type, OWL.NamedIndividual))
    g.add((characterMaterial, RDFS.label, Literal(row['ascension_boss'], datatype = XSD.string)))

    g.add((role, RDF.type, URIRef(gOnto + "Role")))
    g.add((role, RDF.type, OWL.NamedIndividual))
    g.add((role, RDFS.label, Literal(row['role'], datatype = XSD.string)))
    
    g.add((name, URIRef(gOnto + "rarity"), Literal(row['rarity'], datatype = XSD.integer)))
    g.add((name, URIRef(gOnto + "residesAt"), URIRef(gRes + row['region'])))
    g.add((name, URIRef(gOnto + "elementAlignment"), URIRef(gRes + row['vision'])))
    g.add((name, URIRef(gOnto + "usesWeaponType"), URIRef(gOnto + row['weapon_type'])))
    g.add((name, URIRef(gOnto + "hasConstellation"), constellation))
    g.add((name, URIRef(gOnto + "birthday"), Literal(row['birthday'], datatype= XSD.dateTime)))
    g.add((name, URIRef(gOnto + "releaseDate"), Literal(row['release_date'], datatype= XSD.dateTime)))
    g.add((name, URIRef(gOnto + "usesCharacterUpgradeMaterial"), characterMaterial))
    g.add((name, URIRef(gOnto + "isLimitedCharacter"), Literal(row['limited'], datatype = XSD.boolean)))
    g.add((name, URIRef(gOnto + "isArchon"), Literal(row['archon'], datatype = XSD.boolean)))
    g.add((name, URIRef(gOnto + "hasAscensionPassive"), Literal(row['ascension'], datatype = XSD.string)))
    g.add((name, URIRef(gOnto + "hasRole"), role))
    g.add((name, URIRef(gOnto + "hasGender"), Literal(row['gender'], datatype = XSD.string)))

# %%
print(g.serialize(format='turtle'))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinResource:Aether a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aether"^^xsd:string ;
#     genshinOntology:birthday "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Viator ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Aether" .
#
# genshinResource:Albedo a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Albedo"^^xsd:string ;
#     genshinOntology:birthday "2023-09-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Princeps_Cretaceus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Basalt_Pillar ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Albedo" .
#
# genshinResource:Alhaitham a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Alhaitham"^^xsd:string ;
#     genshinOntology:birthday "2023-02-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Dendro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Vultur_Volans ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Pseudo-Stamens ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Alhaitham" .
#
# genshinResource:Aloy a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aloy"^^xsd:string ;
#     genshinOntology:birthday "2023-04-04T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nora_Fortis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Aloy" .
#
# genshinResource:Amber a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Amber"^^xsd:string ;
#     genshinOntology:birthday "2023-08-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lepus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Amber" .
#
# genshinResource:Arataki_Itto a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Arataki_Itto"^^xsd:string ;
#     genshinOntology:birthday "2023-06-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Taurus_Iracundus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Riftborn_Regalia ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Arataki_Itto" .
#
# genshinResource:Baizhu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Baizhu"^^xsd:string ;
#     genshinOntology:birthday "2023-04-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lagenaria ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Baizhu" .
#
# genshinResource:Barbara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Barbara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Crater ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Cleansing_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Barbara" .
#
# genshinResource:Beidou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Beidou"^^xsd:string ;
#     genshinOntology:birthday "2023-02-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "Electro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Victor_Mare ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Beidou" .
#
# genshinResource:Bennett a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Bennett"^^xsd:string ;
#     genshinOntology:birthday "2023-02-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Rota_Calamitas ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Bennett" .
#
# genshinResource:Candace a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Candace"^^xsd:string ;
#     genshinOntology:birthday "2023-05-03T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sagitta_Scutum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Candace" .
#
# genshinResource:Charlotte a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Charlotte"^^xsd:string ;
#     genshinOntology:birthday "2023-04-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Hualina_Veritas ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:fTourbillon_Device ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Charlotte" .
#
# genshinResource:Chongyun a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Chongyun"^^xsd:string ;
#     genshinOntology:birthday "2023-09-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nubis_Caesor ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Chongyun" .
#
# genshinResource:Collei a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Collei"^^xsd:string ;
#     genshinOntology:birthday "2023-05-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leptailurus_Cervarius ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-08-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Majestic_Hooked_Beak ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Collei" .
#
# genshinResource:Cyno a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Cyno"^^xsd:string ;
#     genshinOntology:birthday "2023-06-23T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lupus_Aureus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Cyno" .
#
# genshinResource:Dehya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dehya"^^xsd:string ;
#     genshinOntology:birthday "2023-04-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Mantichora ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-03-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dehya" .
#
# genshinResource:Diluc a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diluc"^^xsd:string ;
#     genshinOntology:birthday "2023-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Noctua ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Diluc" .
#
# genshinResource:Diona a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diona"^^xsd:string ;
#     genshinOntology:birthday "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Feles ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-11-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Diona" .
#
# genshinResource:Dori a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dori"^^xsd:string ;
#     genshinOntology:birthday "2023-12-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Magicae_Lucerna ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dori" .
#
# genshinResource:Eula a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Eula"^^xsd:string ;
#     genshinOntology:birthday "2023-10-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Aphros_Delos ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Eula" .
#
# genshinResource:Faruzan a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Faruzan"^^xsd:string ;
#     genshinOntology:birthday "2023-08-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flosculi_Implexi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-12-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Faruzan" .
#
# genshinResource:Fischl a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Fischl"^^xsd:string ;
#     genshinOntology:birthday "2023-05-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Corvus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Fischl" .
#
# genshinResource:Freminet a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Freminet"^^xsd:string ;
#     genshinOntology:birthday "2023-09-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Automaton ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-09-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Artificed_Spare_Clockwork_Component_-_Coppelius ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Freminet" .
#
# genshinResource:Furina a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Furina"^^xsd:string ;
#     genshinOntology:birthday "2023-10-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Animula_Choragi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon true ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Water_That_Failed_To_Transcend ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Furina" .
#
# genshinResource:Ganyu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Ganyu"^^xsd:string ;
#     genshinOntology:birthday "2023-12-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sinae_Unicornis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-01-12T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Ganyu" .
#
# genshinResource:Gorou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Gorou"^^xsd:string ;
#     genshinOntology:birthday "2023-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Canis_Bellatoris ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Gorou" .
#
# genshinResource:Hu_Tao a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Hu_Tao"^^xsd:string ;
#     genshinOntology:birthday "2023-07-15T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Papilio_Charontis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-03-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Juvenile_Jade ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Hu_Tao" .
#
# genshinResource:Jean a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Jean"^^xsd:string ;
#     genshinOntology:birthday "2023-03-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Healing_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leo_Minor ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hurricane_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Jean" .
#
# genshinResource:Kaedehara_Kazuha a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaedehara_Kazuha"^^xsd:string ;
#     genshinOntology:birthday "2023-10-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Acer_Palmatum ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-06-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Marionette_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaedehara_Kazuha" .
#
# genshinResource:Kaeya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaeya"^^xsd:string ;
#     genshinOntology:birthday "2023-11-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Pavo_Ocellus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaeya" .
#
# genshinResource:Kamisato_Ayaka a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayaka"^^xsd:string ;
#     genshinOntology:birthday "2023-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Grus_Nivis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-07-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayaka" .
#
# genshinResource:Kamisato_Ayato a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayato"^^xsd:string ;
#     genshinOntology:birthday "2023-03-26T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Cypressus_Custos ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Dew_of_Repudation ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayato" .
#
# genshinResource:Kaveh a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaveh"^^xsd:string ;
#     genshinOntology:birthday "2023-07-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Paradisaea ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Quelled_Creeper ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Kaveh" .
#
# genshinResource:Keqing a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Keqing"^^xsd:string ;
#     genshinOntology:birthday "2023-11-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trulla_Cementarii ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Keqing" .
#
# genshinResource:Kirara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kirara"^^xsd:string ;
#     genshinOntology:birthday "2023-01-22T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Arcella ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kirara" .
#
# genshinResource:Klee a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Klee"^^xsd:string ;
#     genshinOntology:birthday "2023-07-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Pyro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trifolium ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-10-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Klee" .
#
# genshinResource:Kujou_Sara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kujou_Sara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flabellum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Storm_Beads ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Kujou_Sara" .
#
# genshinResource:Kuki_Shinobu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kuki_Shinobu"^^xsd:string ;
#     genshinOntology:birthday "2023-07-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Tribulatio_Demptio ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-06-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Runic_Fang ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kuki_Shinobu" .
#
# genshinResource:Layla a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Layla"^^xsd:string ;
#     genshinOntology:birthday "2023-12-19T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Luscinia ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-11-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Caliber ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Layla" .
#
# genshinResource:Lisa a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Lisa"^^xsd:string ;
#     genshinOntology:birthday "2023-06-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Tempus_Fugit ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Lisa" .
#
# genshinResource:Lumine a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Lumine"^^xsd:string ;
#     genshinOntology:birthday "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Viatrix ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Lumine" .
#
# genshinResource:Lynette a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Lynette"^^xsd:string ;
#     genshinOntology:birthday "2023-02-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Anemo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Felis_Alba ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-08-16T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Artificed_Spare_Clockwork_Component_-_Coppelia ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Lynette" .
#
# genshinResource:Lyney a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Lyney"^^xsd:string ;
#     genshinOntology:birthday "2023-02-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Felis_Fuscus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-08-16T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial <http://www.genshin.org/resource/Emperor's_Resolution> ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Lyney" .
#
# genshinResource:Mika a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Mika"^^xsd:string ;
#     genshinOntology:birthday "2023-08-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Palumbus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-03-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Pseudo-Stamens ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Mika" .
#
# genshinResource:Mona a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Mona"^^xsd:string ;
#     genshinOntology:birthday "2023-08-31T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Astrolabos ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Cleansing_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Mona" .
#
# genshinResource:Nahida a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Nahida"^^xsd:string ;
#     genshinOntology:birthday "2023-10-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sapientia_Oromasdis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon true ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-11-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Quelled_Creeper ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Nahida" .
#
# genshinResource:Neuvillette a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Neuvillette"^^xsd:string ;
#     genshinOntology:birthday "2023-12-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leviathan_Judicator ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-09-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Fontemer_Unihorn ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Neuvillette" .
#
# genshinResource:Nilou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Nilou"^^xsd:string ;
#     genshinOntology:birthday "2023-12-03T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lotos_Somno ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-10-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Caliber ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Nilou" .
#
# genshinResource:Ningguang a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Ningguang"^^xsd:string ;
#     genshinOntology:birthday "2023-08-26T00:00:00"^^xsd:dateTime ;
# ...
#     rdfs:label "Hoarfrost_Core"^^xsd:string .
#
# genshinResource:Lightning_Prism a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Lightning_Prism"^^xsd:string .
#
# genshinOntology:PlayableCharacter a owl:Class ;
#     rdfs:comment "Every playable character in genshin has a vision and has some preferred weapon they like using" ;
#     rdfs:subClassOf genshinOntology:Character ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:VisionHolder genshinOntology:WeaponHolder ) ] .
#
# genshinOntology:WeaponType a owl:Class ;
#     rdfs:comment "Types for each Weapon (Bow, Catalyst, Claymore, Polearm and Sword)." ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:elementAlignment a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character having an element . It's made functional because a character cannot have more than 1 element. If they do, it should mean that the two element instances are the same individuals." ;
#     rdfs:range genshinOntology:Element .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Shielder"^^xsd:string ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Geo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Hyperbloom,
#         genshinResource:Quicken .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Healer"^^xsd:string ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Electro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Hyperbloom,
#         genshinResource:Overloaded,
#         genshinResource:Quicken,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Frozen,
#         genshinResource:Hyperbloom,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Swirl .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Pyro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Crystallize,
#         genshinResource:Melt,
#         genshinResource:Overloaded,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Frozen,
#         genshinResource:Melt,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Support"^^xsd:string ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual ;
#     rdfs:label "DPS"^^xsd:string .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %%
g.serialize(destination="afterAddingCharacters.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Adding Enemies (Listen Thorfinn, my son. You have no enemies.)

# %%
df=pd.read_csv('./database/Enemies.csv',sep=",")
df['Name'] = df['Name'].str.replace(' ', '_')
df['DropsMaterial'] = df['DropsMaterial'].str.replace(' ', '_')
df['EnemyType'] = df['EnemyType'].str.replace(' ', '')
df.head()
# Out:
#               Name Element WeakAgainst EnemyType    DropsMaterial
# 0        Hilichurl   Anemo     Electro    Normal   Firm_Arrowhead
# 1  Anemo_Samachurl   Anemo     Electro     Elite  Divining_Scroll
# 2  Hydro_Samachurl   Hydro        Pyro     Elite  Divining_Scroll
# 3   Cryo_Samachurl    Cryo        Pyro     Elite  Divining_Scroll
# 4        Mitachurl   Anemo     Electro     Elite   Firm_Arrowhead

# %%
for index, row in df.iterrows():
    name = URIRef(gRes+row['Name'])
    material = URIRef(gRes+row['DropsMaterial'])
    
    g.add((name, RDF.type, URIRef(gOnto + "Enemy")))    
    g.add((name, RDF.type, OWL.NamedIndividual))
    g.add((name, FOAF.name, Literal(row['Name'])))
    g.add((name, RDFS.label, Literal(row['Name'], datatype = XSD.string)))
    
    g.add((material, RDF.type, URIRef(gOnto + "Material")))
    g.add((material, RDF.type, OWL.NamedIndividual))
    g.add((material, RDFS.label, Literal(row['DropsMaterial'], datatype = XSD.string)))
    
    g.add((name, URIRef(gOnto + "elementAlignment"), URIRef(gRes + row['Element'])))
    g.add((name, URIRef(gOnto + "enemyWeakAgainst"), URIRef(gRes + row['WeakAgainst'])))
    g.add((name, URIRef(gOnto + "isEnemyType"), URIRef(gOnto + row['EnemyType'])))
    g.add((name, URIRef(gOnto + "dropsMaterial"), material))

# %%
print(g.serialize(format='turtle'))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinResource:Aether a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aether"^^xsd:string ;
#     genshinOntology:birthday "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Viator ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Aether" .
#
# genshinResource:Albedo a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Albedo"^^xsd:string ;
#     genshinOntology:birthday "2023-09-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Princeps_Cretaceus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Basalt_Pillar ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Albedo" .
#
# genshinResource:Alhaitham a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Alhaitham"^^xsd:string ;
#     genshinOntology:birthday "2023-02-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Dendro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Vultur_Volans ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Pseudo-Stamens ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Alhaitham" .
#
# genshinResource:Aloy a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aloy"^^xsd:string ;
#     genshinOntology:birthday "2023-04-04T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nora_Fortis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Aloy" .
#
# genshinResource:Amber a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Amber"^^xsd:string ;
#     genshinOntology:birthday "2023-08-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lepus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Amber" .
#
# genshinResource:Andrius a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Andrius"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Sigh> ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Andrius" .
#
# genshinResource:Anemo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vayuda_Turquoise_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Anemo_Hypostasis" .
#
# genshinResource:Anemo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Anemo_Samachurl" .
#
# genshinResource:Anemo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Anemo_Slime" .
#
# genshinResource:Arataki_Itto a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Arataki_Itto"^^xsd:string ;
#     genshinOntology:birthday "2023-06-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Taurus_Iracundus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Riftborn_Regalia ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Arataki_Itto" .
#
# genshinResource:Azhdaha a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Azhdaha"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Fragment_of_Innocence ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Azhdaha" .
#
# genshinResource:Baizhu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Baizhu"^^xsd:string ;
#     genshinOntology:birthday "2023-04-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lagenaria ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Baizhu" .
#
# genshinResource:Barbara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Barbara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Crater ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Cleansing_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Barbara" .
#
# genshinResource:Beidou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Beidou"^^xsd:string ;
#     genshinOntology:birthday "2023-02-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "Electro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Victor_Mare ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Beidou" .
#
# genshinResource:Bennett a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Bennett"^^xsd:string ;
#     genshinOntology:birthday "2023-02-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Rota_Calamitas ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Bennett" .
#
# genshinResource:Candace a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Candace"^^xsd:string ;
#     genshinOntology:birthday "2023-05-03T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sagitta_Scutum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Candace" .
#
# genshinResource:Charlotte a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Charlotte"^^xsd:string ;
#     genshinOntology:birthday "2023-04-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Hualina_Veritas ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:fTourbillon_Device ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Charlotte" .
#
# genshinResource:Childe a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Childe"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Shard_of_a_Foul_Legacy ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Childe" .
#
# genshinResource:Chongyun a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Chongyun"^^xsd:string ;
#     genshinOntology:birthday "2023-09-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nubis_Caesor ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Chongyun" .
#
# genshinResource:Cicin_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cicin_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cicin_Mage" .
#
# genshinResource:Collei a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Collei"^^xsd:string ;
#     genshinOntology:birthday "2023-05-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leptailurus_Cervarius ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-08-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Majestic_Hooked_Beak ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Collei" .
#
# genshinResource:Cryo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Abyss_Mage" .
#
# genshinResource:Cryo_Regisvine a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Regisvine"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Frozen_Seed ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Cryo_Regisvine" .
#
# genshinResource:Cryo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Samachurl" .
#
# genshinResource:Cryo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Cryo_Slime" .
#
# genshinResource:Cyno a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Cyno"^^xsd:string ;
#     genshinOntology:birthday "2023-06-23T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lupus_Aureus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Cyno" .
#
# genshinResource:Dehya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dehya"^^xsd:string ;
#     genshinOntology:birthday "2023-04-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Mantichora ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-03-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dehya" .
#
# genshinResource:Dendro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Dendro_Slime" .
#
# genshinResource:Diluc a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diluc"^^xsd:string ;
#     genshinOntology:birthday "2023-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Noctua ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Diluc" .
#
# genshinResource:Diona a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diona"^^xsd:string ;
#     genshinOntology:birthday "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Feles ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-11-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Diona" .
#
# genshinResource:Dori a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dori"^^xsd:string ;
#     genshinOntology:birthday "2023-12-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Magicae_Lucerna ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dori" .
#
# genshinResource:Dvalin a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dvalin"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Claw> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Dvalin" .
#
# genshinResource:Electro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Electro_Abyss_Mage" .
#
# genshinResource:Electro_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vajrada_Amethyst_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Electro_Hypostasis" .
#
# genshinResource:Electro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Electro_Slime" .
#
# genshinResource:Eula a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Eula"^^xsd:string ;
#     genshinOntology:birthday "2023-10-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Aphros_Delos ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Eula" .
#
# genshinResource:Faruzan a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Faruzan"^^xsd:string ;
#     genshinOntology:birthday "2023-08-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flosculi_Implexi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-12-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Faruzan" .
#
# genshinResource:Fatui_Skirmisher a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Fatui_Skirmisher"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Sergeant's_Insignia> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Fatui_Skirmisher" .
#
# genshinResource:Fischl a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Fischl"^^xsd:string ;
#     genshinOntology:birthday "2023-05-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Corvus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Fischl" .
#
# genshinResource:Freminet a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Freminet"^^xsd:string ;
#     genshinOntology:birthday "2023-09-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Automaton ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-09-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Artificed_Spare_Clockwork_Component_-_Coppelius ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Freminet" .
#
# genshinResource:Furina a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Furina"^^xsd:string ;
#     genshinOntology:birthday "2023-10-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Animula_Choragi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon true ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Water_That_Failed_To_Transcend ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Furina" .
#
# genshinResource:Ganyu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Ganyu"^^xsd:string ;
#     genshinOntology:birthday "2023-12-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sinae_Unicornis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-01-12T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Ganyu" .
#
# genshinResource:Geo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Geo_Abyss_Mage" .
#
# genshinResource:Geo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Prithiva_Topaz_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Geo_Hypostasis" .
#
# genshinResource:Geo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Geo_Slime" .
#
# genshinResource:Gorou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Gorou"^^xsd:string ;
#     genshinOntology:birthday "2023-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Canis_Bellatoris ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Gorou" .
#
# genshinResource:Hilichurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hilichurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Firm_Arrowhead ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Hilichurl" .
#
# genshinResource:Hu_Tao a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Hu_Tao"^^xsd:string ;
#     genshinOntology:birthday "2023-07-15T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Papilio_Charontis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-03-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Juvenile_Jade ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Hu_Tao" .
#
# genshinResource:Hydro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Abyss_Mage" .
#
# genshinResource:Hydro_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Samachurl" .
#
# genshinResource:Jean a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Jean"^^xsd:string ;
#     genshinOntology:birthday "2023-03-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Healing_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leo_Minor ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hurricane_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Jean" .
#
# genshinResource:Kaedehara_Kazuha a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaedehara_Kazuha"^^xsd:string ;
#     genshinOntology:birthday "2023-10-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Acer_Palmatum ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-06-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Marionette_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaedehara_Kazuha" .
#
# genshinResource:Kaeya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaeya"^^xsd:string ;
#     genshinOntology:birthday "2023-11-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Pavo_Ocellus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaeya" .
#
# genshinResource:Kamisato_Ayaka a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayaka"^^xsd:string ;
#     genshinOntology:birthday "2023-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Grus_Nivis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-07-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayaka" .
#
# genshinResource:Kamisato_Ayato a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayato"^^xsd:string ;
#     genshinOntology:birthday "2023-03-26T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Cypressus_Custos ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Dew_of_Repudation ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayato" .
#
# genshinResource:Kaveh a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaveh"^^xsd:string ;
#     genshinOntology:birthday "2023-07-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Paradisaea ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Quelled_Creeper ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Kaveh" .
#
# genshinResource:Keqing a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Keqing"^^xsd:string ;
#     genshinOntology:birthday "2023-11-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trulla_Cementarii ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Keqing" .
#
# genshinResource:Kirara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kirara"^^xsd:string ;
#     genshinOntology:birthday "2023-01-22T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Arcella ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kirara" .
#
# genshinResource:Klee a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Klee"^^xsd:string ;
#     genshinOntology:birthday "2023-07-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Pyro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trifolium ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-10-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Klee" .
#
# genshinResource:Kujou_Sara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kujou_Sara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flabellum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Storm_Beads ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Kujou_Sara" .
#
# genshinResource:Kuki_Shinobu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kuki_Shinobu"^^xsd:string ;
#     genshinOntology:birthday "2023-07-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Tribulatio_Demptio ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
# ...
#     rdfs:comment "Any character having an element . It's made functional because a character cannot have more than 1 element. If they do, it should mean that the two element instances are the same individuals." ;
#     rdfs:range genshinOntology:Element .
#
# genshinResource:Lightning_Prism a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Lightning_Prism"^^xsd:string .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Shielder"^^xsd:string ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinOntology:Normal a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Normal ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Hyperbloom,
#         genshinResource:Quicken .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Healer"^^xsd:string ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Geo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Elite a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Elite ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Frozen,
#         genshinResource:Hyperbloom,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Pyro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Crystallize,
#         genshinResource:Melt,
#         genshinResource:Overloaded,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Electro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Hyperbloom,
#         genshinResource:Overloaded,
#         genshinResource:Quicken,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Support"^^xsd:string ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Frozen,
#         genshinResource:Melt,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Swirl .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual ;
#     rdfs:label "DPS"^^xsd:string .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %%
g.serialize(destination="afterAddingEnemies.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Adding Weapons

# %%
df=pd.read_csv('./database/Weapons.csv',sep=",")
df['Name'] = df['Name'].str.replace(' ', '_')
df['UpgradeMaterial'] = df['UpgradeMaterial'].str.replace(' ', '_')
df.head()
# Out:
#                               Name      Type  Rarity  \
# 0                Wolf's_Gravestone  Claymore       5
# 1                     Skyward_Harp       Bow       5
# 2     Primordial_Jade_Winged-Spear   Polearm       5
# 3                   Aquila_Favonia     Sword       5
# 4  Lost_Prayer_to_the_Sacred_Winds  Catalyst       5
#
#               UpgradeMaterial
# 0            Tusk_of_the_Wolf
# 1   Luminous_Sands_from_Guyun
# 2                   Jade_Wing
# 3            Tusk_of_the_Wolf
# 4  Tile_of_Decarabian's_Tower

# %%
for index, row in df.iterrows():
    name = URIRef(gRes+row['Name'])
    weaponMaterial = URIRef(gRes+row['UpgradeMaterial'])
    
    g.add((name, RDF.type, URIRef(gOnto + "Weapon")))    
    g.add((name, RDF.type, OWL.NamedIndividual))
    g.add((name, FOAF.name, Literal(row['Name'])))
    g.add((name, RDFS.label, Literal(row['Name'], datatype = XSD.string)))
    
    g.add((weaponMaterial, RDF.type, URIRef(gOnto + "Material")))
    g.add((weaponMaterial, RDF.type, OWL.NamedIndividual))
    g.add((weaponMaterial, FOAF.name, Literal(row['UpgradeMaterial'])))
    g.add((weaponMaterial, RDFS.label, Literal(row['UpgradeMaterial'], datatype = XSD.string)))
    
    g.add((name, URIRef(gOnto + "isWeaponType"), URIRef(gOnto + row['Type'])))
    g.add((name, URIRef(gOnto + "rarity"), Literal(row['Rarity'], datatype = XSD.integer)))
    g.add((name, URIRef(gOnto + "usesWeaponUpgradeMaterial"), weaponMaterial))

# %%
print(g.serialize(format='turtle'))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinResource:Aether a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aether"^^xsd:string ;
#     genshinOntology:birthday "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Viator ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Aether" .
#
# genshinResource:Albedo a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Albedo"^^xsd:string ;
#     genshinOntology:birthday "2023-09-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Princeps_Cretaceus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Basalt_Pillar ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Albedo" .
#
# genshinResource:Alhaitham a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Alhaitham"^^xsd:string ;
#     genshinOntology:birthday "2023-02-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Dendro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Vultur_Volans ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Pseudo-Stamens ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Alhaitham" .
#
# genshinResource:Aloy a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aloy"^^xsd:string ;
#     genshinOntology:birthday "2023-04-04T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nora_Fortis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Aloy" .
#
# genshinResource:Amber a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Amber"^^xsd:string ;
#     genshinOntology:birthday "2023-08-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lepus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Amber" .
#
# genshinResource:Andrius a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Andrius"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Sigh> ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Andrius" .
#
# genshinResource:Anemo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vayuda_Turquoise_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Anemo_Hypostasis" .
#
# genshinResource:Anemo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Anemo_Samachurl" .
#
# genshinResource:Anemo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Anemo_Slime" .
#
# genshinResource:Aquila_Favonia a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Aquila_Favonia"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Sword ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Tusk_of_the_Wolf ;
#     foaf:name "Aquila_Favonia" .
#
# genshinResource:Arataki_Itto a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Arataki_Itto"^^xsd:string ;
#     genshinOntology:birthday "2023-06-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Taurus_Iracundus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Riftborn_Regalia ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Arataki_Itto" .
#
# genshinResource:Azhdaha a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Azhdaha"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Fragment_of_Innocence ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Azhdaha" .
#
# genshinResource:Baizhu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Baizhu"^^xsd:string ;
#     genshinOntology:birthday "2023-04-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lagenaria ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Baizhu" .
#
# genshinResource:Barbara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Barbara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Crater ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Cleansing_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Barbara" .
#
# genshinResource:Beidou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Beidou"^^xsd:string ;
#     genshinOntology:birthday "2023-02-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "Electro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Victor_Mare ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Beidou" .
#
# genshinResource:Bennett a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Bennett"^^xsd:string ;
#     genshinOntology:birthday "2023-02-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Rota_Calamitas ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Bennett" .
#
# genshinResource:Candace a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Candace"^^xsd:string ;
#     genshinOntology:birthday "2023-05-03T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sagitta_Scutum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Candace" .
#
# genshinResource:Charlotte a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Charlotte"^^xsd:string ;
#     genshinOntology:birthday "2023-04-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Hualina_Veritas ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:fTourbillon_Device ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Charlotte" .
#
# genshinResource:Childe a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Childe"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Shard_of_a_Foul_Legacy ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Childe" .
#
# genshinResource:Chongyun a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Chongyun"^^xsd:string ;
#     genshinOntology:birthday "2023-09-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nubis_Caesor ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Chongyun" .
#
# genshinResource:Cicin_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cicin_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cicin_Mage" .
#
# genshinResource:Collei a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Collei"^^xsd:string ;
#     genshinOntology:birthday "2023-05-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leptailurus_Cervarius ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-08-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Majestic_Hooked_Beak ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Collei" .
#
# genshinResource:Compound_Bow a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Compound_Bow"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Bow ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial <http://www.genshin.org/resource/Tile_of_Decarabian's_Tower> ;
#     foaf:name "Compound_Bow" .
#
# genshinResource:Crescent_Pike a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Crescent_Pike"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Mist_Veiled_Lead_Elixir ;
#     foaf:name "Crescent_Pike" .
#
# genshinResource:Cryo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Abyss_Mage" .
#
# genshinResource:Cryo_Regisvine a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Regisvine"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Frozen_Seed ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Cryo_Regisvine" .
#
# genshinResource:Cryo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Samachurl" .
#
# genshinResource:Cryo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Cryo_Slime" .
#
# genshinResource:Cyno a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Cyno"^^xsd:string ;
#     genshinOntology:birthday "2023-06-23T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lupus_Aureus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Cyno" .
#
# genshinResource:Deathmatch a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Deathmatch"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Deathmatch" .
#
# genshinResource:Dehya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dehya"^^xsd:string ;
#     genshinOntology:birthday "2023-04-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Mantichora ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-03-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dehya" .
#
# genshinResource:Dendro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Dendro_Slime" .
#
# genshinResource:Diluc a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diluc"^^xsd:string ;
#     genshinOntology:birthday "2023-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Noctua ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Diluc" .
#
# genshinResource:Diona a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diona"^^xsd:string ;
#     genshinOntology:birthday "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Feles ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-11-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Diona" .
#
# genshinResource:Dori a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dori"^^xsd:string ;
#     genshinOntology:birthday "2023-12-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Magicae_Lucerna ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dori" .
#
# <http://www.genshin.org/resource/Dragon's_Bane> a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Dragon's_Bane"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Dragon's_Bane" .
#
# genshinResource:Dvalin a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dvalin"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Claw> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Dvalin" .
#
# genshinResource:Electro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Electro_Abyss_Mage" .
#
# genshinResource:Electro_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vajrada_Amethyst_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Electro_Hypostasis" .
#
# genshinResource:Electro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Electro_Slime" .
#
# genshinResource:Eula a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Eula"^^xsd:string ;
#     genshinOntology:birthday "2023-10-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Aphros_Delos ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Eula" .
#
# genshinResource:Eye_of_Perception a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Eye_of_Perception"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Catalyst ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Ring_of_Boreas ;
#     foaf:name "Eye_of_Perception" .
#
# genshinResource:Faruzan a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Faruzan"^^xsd:string ;
#     genshinOntology:birthday "2023-08-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flosculi_Implexi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-12-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Faruzan" .
#
# genshinResource:Fatui_Skirmisher a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Fatui_Skirmisher"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Sergeant's_Insignia> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Fatui_Skirmisher" .
#
# genshinResource:Favonius_Greatsword a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Favonius_Greatsword"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Claymore ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Favonius_Greatsword" .
#
# genshinResource:Favonius_Warbow a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Favonius_Warbow"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Bow ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Favonius_Warbow" .
#
# genshinResource:Fischl a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Fischl"^^xsd:string ;
#     genshinOntology:birthday "2023-05-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Corvus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Fischl" .
#
# genshinResource:Freminet a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Freminet"^^xsd:string ;
#     genshinOntology:birthday "2023-09-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Automaton ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-09-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Artificed_Spare_Clockwork_Component_-_Coppelius ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Freminet" .
#
# genshinResource:Furina a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Furina"^^xsd:string ;
#     genshinOntology:birthday "2023-10-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Animula_Choragi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon true ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Water_That_Failed_To_Transcend ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Furina" .
#
# genshinResource:Ganyu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Ganyu"^^xsd:string ;
#     genshinOntology:birthday "2023-12-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sinae_Unicornis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-01-12T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Ganyu" .
#
# genshinResource:Geo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Geo_Abyss_Mage" .
#
# genshinResource:Geo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Prithiva_Topaz_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Geo_Hypostasis" .
#
# genshinResource:Geo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Geo_Slime" .
#
# genshinResource:Gorou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Gorou"^^xsd:string ;
#     genshinOntology:birthday "2023-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Canis_Bellatoris ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Gorou" .
#
# genshinResource:Hilichurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hilichurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Firm_Arrowhead ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Hilichurl" .
#
# genshinResource:Hu_Tao a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Hu_Tao"^^xsd:string ;
#     genshinOntology:birthday "2023-07-15T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Papilio_Charontis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-03-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Juvenile_Jade ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Hu_Tao" .
#
# genshinResource:Hydro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Abyss_Mage" .
#
# genshinResource:Hydro_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Samachurl" .
#
# genshinResource:Jean a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Jean"^^xsd:string ;
#     genshinOntology:birthday "2023-03-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Healing_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leo_Minor ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hurricane_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Jean" .
#
# genshinResource:Kaedehara_Kazuha a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaedehara_Kazuha"^^xsd:string ;
#     genshinOntology:birthday "2023-10-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Acer_Palmatum ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-06-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Marionette_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaedehara_Kazuha" .
#
# genshinResource:Kaeya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaeya"^^xsd:string ;
#     genshinOntology:birthday "2023-11-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Pavo_Ocellus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaeya" .
#
# genshinResource:Kamisato_Ayaka a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayaka"^^xsd:string ;
#     genshinOntology:birthday "2023-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Grus_Nivis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-07-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayaka" .
#
# genshinResource:Kamisato_Ayato a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayato"^^xsd:string ;
#     genshinOntology:birthday "2023-03-26T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Cypressus_Custos ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Dew_of_Repudation ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayato" .
#
# genshinResource:Kaveh a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaveh"^^xsd:string ;
#     genshinOntology:birthday "2023-07-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Paradisaea ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Quelled_Creeper ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Kaveh" .
#
# genshinResource:Keqing a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Keqing"^^xsd:string ;
#     genshinOntology:birthday "2023-11-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trulla_Cementarii ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Keqing" .
#
# genshinResource:Kirara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kirara"^^xsd:string ;
#     genshinOntology:birthday "2023-01-22T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Arcella ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
# ...
#     rdfs:range genshinOntology:Element .
#
# genshinResource:Basalt_Pillar a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Basalt_Pillar"^^xsd:string ;
#     foaf:name "Basalt_Pillar" .
#
# genshinResource:Lightning_Prism a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Lightning_Prism"^^xsd:string .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Shielder"^^xsd:string ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinOntology:Normal a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Normal ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Hyperbloom,
#         genshinResource:Quicken .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Healer"^^xsd:string ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Geo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize .
#
# genshinOntology:Elite a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Elite ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Frozen,
#         genshinResource:Hyperbloom,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Pyro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Crystallize,
#         genshinResource:Melt,
#         genshinResource:Overloaded,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Electro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Hyperbloom,
#         genshinResource:Overloaded,
#         genshinResource:Quicken,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Support"^^xsd:string ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Frozen,
#         genshinResource:Melt,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Swirl .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual ;
#     rdfs:label "DPS"^^xsd:string .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %%
g.serialize(destination="afterAddingWeapons.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Linking with Wikidata

# %%
# Keqing
character = URIRef(gRes + 'Keqing')
wikidataLink = URIRef(wd + 'Q107287676')
g.add((character, OWL.sameAs, wikidataLink))

# Yun Jin
character = URIRef(gRes + 'Yun_Jin')
wikidataLink = URIRef(wd + 'Q110653384')
g.add((character, OWL.sameAs, wikidataLink))

# Shenhe
character = URIRef(gRes + 'Shenhe')
wikidataLink = URIRef(wd + 'Q110677319')
g.add((character, OWL.sameAs, wikidataLink))

# Ganyu
character = URIRef(gRes + 'Ganyu')
wikidataLink = URIRef(wd + 'Q107618618')
g.add((character, OWL.sameAs, wikidataLink))

# Diluc
character = URIRef(gRes + 'Diluc')
wikidataLink = URIRef(wd + 'Q107263978')
g.add((character, OWL.sameAs, wikidataLink))

# Hu Tao
character = URIRef(gRes + 'Barbara')
wikidataLink = URIRef(wd + 'Q110911467')
g.add((character, OWL.sameAs, wikidataLink))

# Yanfei
character = URIRef(gRes + 'Yanfei')
wikidataLink = URIRef(wd + 'Q110965539')
g.add((character, OWL.sameAs, wikidataLink))

# Amber
character = URIRef(gRes + 'Amber')
wikidataLink = URIRef(wd + 'Q111008775')
g.add((character, OWL.sameAs, wikidataLink))

# Xiangling
character = URIRef(gRes + 'Xiangling')
wikidataLink = URIRef(wd + 'Q111018815')
g.add((character, OWL.sameAs, wikidataLink))

# Noelle
character = URIRef(gRes + 'Noelle')
wikidataLink = URIRef(wd + 'Q107291860')
g.add((character, OWL.sameAs, wikidataLink))

# Eula
character = URIRef(gRes + 'Eula')
wikidataLink = URIRef(wd + 'Q111079705')
g.add((character, OWL.sameAs, wikidataLink))

# Lisa
character = URIRef(gRes + 'Lisa')
wikidataLink = URIRef(wd + 'Q111133790')
g.add((character, OWL.sameAs, wikidataLink))

# Ningguang
character = URIRef(gRes + 'Ningguang')
wikidataLink = URIRef(wd + 'Q111180134')
g.add((character, OWL.sameAs, wikidataLink))

# Yae Miko
character = URIRef(gRes + 'Yae_Miko')
wikidataLink = URIRef(wd + 'Q111631165')
g.add((character, OWL.sameAs, wikidataLink))

# Kazuha
character = URIRef(gRes + 'Kaedehara_Kazuha')
wikidataLink = URIRef(wd + 'Q111684393')
g.add((character, OWL.sameAs, wikidataLink))

# Raiden
character = URIRef(gRes + 'Raiden_Shogun')
wikidataLink = URIRef(wd + 'Q111655115')
g.add((character, OWL.sameAs, wikidataLink))

# Sucrose
character = URIRef(gRes + 'Sucrose')
wikidataLink = URIRef(wd + 'Q112220215')
g.add((character, OWL.sameAs, wikidataLink))

# Chongyun
character = URIRef(gRes + 'Chongyun')
wikidataLink = URIRef(wd + 'Q107291862')
g.add((character, OWL.sameAs, wikidataLink))

# Ayaka
character = URIRef(gRes + 'Kamisato_Ayaka')
wikidataLink = URIRef(wd + 'Q107618679')
g.add((character, OWL.sameAs, wikidataLink))

# Yoimiya
character = URIRef(gRes + 'Yoimiya')
wikidataLink = URIRef(wd + 'Q113493715')
g.add((character, OWL.sameAs, wikidataLink))

# Fischl
character = URIRef(gRes + 'Fischl')
wikidataLink = URIRef(wd + 'Q113499833')
g.add((character, OWL.sameAs, wikidataLink))

# Thoma
character = URIRef(gRes + 'Thoma')
wikidataLink = URIRef(wd + 'Q113668570')
g.add((character, OWL.sameAs, wikidataLink))

# Nahida
character = URIRef(gRes + 'Nahida')
wikidataLink = URIRef(wd + 'Q115232300')
g.add((character, OWL.sameAs, wikidataLink))

# Xiao
character = URIRef(gRes + 'Xiao')
wikidataLink = URIRef(wd + 'Q107263982')
g.add((character, OWL.sameAs, wikidataLink))

# Qiqi
character = URIRef(gRes + 'Qiqi')
wikidataLink = URIRef(wd + 'Q107287683')
g.add((character, OWL.sameAs, wikidataLink))

# Yelan
character = URIRef(gRes + 'Yelan')
wikidataLink = URIRef(wd + 'Q117195714')
g.add((character, OWL.sameAs, wikidataLink))

# Collei
character = URIRef(gRes + 'Collei')
wikidataLink = URIRef(wd + 'Q118153805')
g.add((character, OWL.sameAs, wikidataLink))

# Kokomi
character = URIRef(gRes + 'Sangonomiya_Kokomi')
wikidataLink = URIRef(wd + 'Q119998675')
g.add((character, OWL.sameAs, wikidataLink))

# Heizou
character = URIRef(gRes + 'Shikanoin_Heizou')
wikidataLink = URIRef(wd + 'Q120994155')
g.add((character, OWL.sameAs, wikidataLink))

# Candace
character = URIRef(gRes + 'Candace')
wikidataLink = URIRef(wd + 'Q121919991')
g.add((character, OWL.sameAs, wikidataLink))
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %%
print(g.serialize(format='turtle'))
# Out:
# @prefix : <http://www.genshin.org/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix genshinOntology: <http://www.genshin.org/ontology/> .
# @prefix genshinResource: <http://www.genshin.org/resource/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix swrl: <http://www.w3.org/2003/11/swrl#> .
# @prefix swrla: <http://swrl.stanford.edu/ontologies/3.3/swrla.owl#> .
# @prefix wd: <http://www.wikidata.org/entity/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# swrla:isRuleEnabled a owl:AnnotationProperty .
#
# genshinOntology: a owl:Ontology ;
#     owl:versionIRI <http://www.genshin.org/ontology/1.0.0/> .
#
# genshinOntology:AdvancedReaction a owl:Class ;
#     rdfs:comment "Those specific reactions where more than 2 elements can participate in" ;
#     rdfs:subClassOf genshinOntology:Reaction ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:minQualifiedCardinality "3"^^xsd:nonNegativeInteger ;
#             owl:onClass genshinOntology:Element ;
#             owl:onProperty genshinOntology:requiresElement ] .
#
# genshinOntology:Archon a owl:Class ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Character [ a owl:Restriction ;
#                         owl:hasValue true ;
#                         owl:onProperty genshinOntology:isArchon ] ) ] .
#
# genshinOntology:DamageDealer a owl:Class ;
#     rdfs:comment "Prioritizes in dealing damage to the enemy" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:DPS ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:birthday a owl:DatatypeProperty ;
#     rdfs:comment "Birthday of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:causesReaction a owl:ObjectProperty ;
#     rdfs:comment "Any element that can cause a reaction" ;
#     rdfs:domain genshinOntology:Element ;
#     rdfs:range genshinOntology:Reaction ;
#     owl:inverseOf genshinOntology:requiresElement .
#
# genshinOntology:dropsMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any enemy which drops a material" ;
#     rdfs:domain genshinOntology:Enemy ;
#     rdfs:range genshinOntology:Material .
#
# genshinOntology:hasAscensionPassive a owl:DatatypeProperty ;
#     rdfs:comment "Every character has a bonus given to his stats whenever you level this up. This property points to that bonus" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasConstellation a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:comment "Any character that has a constellation. This is mentioned in the database and has been made inverse functional because a constellation cannot belong to more than 1 character. If that case ever happens, then both character individuals are the same individual" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:Constellation .
#
# genshinOntology:hasGender a owl:DatatypeProperty ;
#     rdfs:comment "Gender of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:string .
#
# genshinOntology:hasResident a owl:ObjectProperty ;
#     rdfs:comment "A region that houses any character" ;
#     owl:inverseOf genshinOntology:residesAt .
#
# genshinOntology:isLimitedCharacter a owl:DatatypeProperty ;
#     rdfs:comment "Boolean value denoting if that character was limited or not (limited means that you can only get them during certain times)" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:boolean .
#
# genshinOntology:rarity a owl:DatatypeProperty ;
#     rdfs:comment "Rarity of a weapon or character" ;
#     rdfs:range xsd:integer .
#
# genshinOntology:releaseDate a owl:DatatypeProperty ;
#     rdfs:comment "Release date of a character" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range xsd:dateTime .
#
# genshinOntology:usesCharacterUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a character. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Character ;
#     rdfs:range genshinOntology:CharacterUpgradeMaterial .
#
# genshinOntology:usesWeaponUpgradeMaterial a owl:ObjectProperty ;
#     rdfs:comment "Any material used by a weapon. This is mentioned in the database" ;
#     rdfs:domain genshinOntology:Weapon ;
#     rdfs:range genshinOntology:WeaponUpgradeMaterial .
#
# genshinResource:Aether a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aether"^^xsd:string ;
#     genshinOntology:birthday "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Viator ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Aether" .
#
# genshinResource:Albedo a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Albedo"^^xsd:string ;
#     genshinOntology:birthday "2023-09-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Princeps_Cretaceus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Basalt_Pillar ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Albedo" .
#
# genshinResource:Alhaitham a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Alhaitham"^^xsd:string ;
#     genshinOntology:birthday "2023-02-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Dendro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Vultur_Volans ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Pseudo-Stamens ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Alhaitham" .
#
# genshinResource:Aloy a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Aloy"^^xsd:string ;
#     genshinOntology:birthday "2023-04-04T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nora_Fortis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-09-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Aloy" .
#
# genshinResource:Amber a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Amber"^^xsd:string ;
#     genshinOntology:birthday "2023-08-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lepus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     owl:sameAs wd:Q111008775 ;
#     foaf:name "Amber" .
#
# genshinResource:Andrius a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Andrius"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Sigh> ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Andrius" .
#
# genshinResource:Anemo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vayuda_Turquoise_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Anemo_Hypostasis" .
#
# genshinResource:Anemo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Anemo_Samachurl" .
#
# genshinResource:Anemo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Anemo_Slime" .
#
# genshinResource:Aquila_Favonia a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Aquila_Favonia"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Sword ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Tusk_of_the_Wolf ;
#     foaf:name "Aquila_Favonia" .
#
# genshinResource:Arataki_Itto a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Arataki_Itto"^^xsd:string ;
#     genshinOntology:birthday "2023-06-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Taurus_Iracundus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Riftborn_Regalia ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Arataki_Itto" .
#
# genshinResource:Azhdaha a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Azhdaha"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Fragment_of_Innocence ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Azhdaha" .
#
# genshinResource:Baizhu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Baizhu"^^xsd:string ;
#     genshinOntology:birthday "2023-04-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lagenaria ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Evergloom_Ring ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Baizhu" .
#
# genshinResource:Barbara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Barbara"^^xsd:string ;
#     genshinOntology:birthday "2023-07-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Crater ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Cleansing_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     owl:sameAs wd:Q110911467 ;
#     foaf:name "Barbara" .
#
# genshinResource:Beidou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Beidou"^^xsd:string ;
#     genshinOntology:birthday "2023-02-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "Electro_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Victor_Mare ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Beidou" .
#
# genshinResource:Bennett a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Bennett"^^xsd:string ;
#     genshinOntology:birthday "2023-02-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Rota_Calamitas ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Bennett" .
#
# genshinResource:Candace a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Candace"^^xsd:string ;
#     genshinOntology:birthday "2023-05-03T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sagitta_Scutum ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     owl:sameAs wd:Q121919991 ;
#     foaf:name "Candace" .
#
# genshinResource:Charlotte a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Charlotte"^^xsd:string ;
#     genshinOntology:birthday "2023-04-10T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Hualina_Veritas ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:fTourbillon_Device ;
#     genshinOntology:usesWeaponType genshinOntology:Catalyst ;
#     foaf:name "Charlotte" .
#
# genshinResource:Childe a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Childe"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Shard_of_a_Foul_Legacy ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Childe" .
#
# genshinResource:Chongyun a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Chongyun"^^xsd:string ;
#     genshinOntology:birthday "2023-09-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Nubis_Caesor ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     owl:sameAs wd:Q107291862 ;
#     foaf:name "Chongyun" .
#
# genshinResource:Cicin_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cicin_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cicin_Mage" .
#
# genshinResource:Collei a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Collei"^^xsd:string ;
#     genshinOntology:birthday "2023-05-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leptailurus_Cervarius ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-08-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Majestic_Hooked_Beak ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     owl:sameAs wd:Q118153805 ;
#     foaf:name "Collei" .
#
# genshinResource:Compound_Bow a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Compound_Bow"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Bow ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial <http://www.genshin.org/resource/Tile_of_Decarabian's_Tower> ;
#     foaf:name "Compound_Bow" .
#
# genshinResource:Crescent_Pike a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Crescent_Pike"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Mist_Veiled_Lead_Elixir ;
#     foaf:name "Crescent_Pike" .
#
# genshinResource:Cryo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Abyss_Mage" .
#
# genshinResource:Cryo_Regisvine a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Regisvine"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Frozen_Seed ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Cryo_Regisvine" .
#
# genshinResource:Cryo_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Cryo_Samachurl" .
#
# genshinResource:Cryo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Cryo_Slime" .
#
# genshinResource:Cyno a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Cyno"^^xsd:string ;
#     genshinOntology:birthday "2023-06-23T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Lupus_Aureus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Cyno" .
#
# genshinResource:Deathmatch a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Deathmatch"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Deathmatch" .
#
# genshinResource:Dehya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dehya"^^xsd:string ;
#     genshinOntology:birthday "2023-04-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Mantichora ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-03-01T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dehya" .
#
# genshinResource:Dendro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Dendro_Slime" .
#
# genshinResource:Diluc a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diluc"^^xsd:string ;
#     genshinOntology:birthday "2023-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Noctua ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Everflame_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     owl:sameAs wd:Q107263978 ;
#     foaf:name "Diluc" .
#
# genshinResource:Diona a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Diona"^^xsd:string ;
#     genshinOntology:birthday "2023-01-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Cryo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Feles ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Shielder ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-11-11T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Diona" .
#
# genshinResource:Dori a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Dori"^^xsd:string ;
#     genshinOntology:birthday "2023-12-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "HP"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Magicae_Lucerna ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2022-09-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Thunderclap_Fruitcore ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Dori" .
#
# <http://www.genshin.org/resource/Dragon's_Bane> a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Dragon's_Bane"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Polearm ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Dragon's_Bane" .
#
# genshinResource:Dvalin a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Dvalin"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Dvalin's_Claw> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Cryo ;
#     genshinOntology:isEnemyType genshinOntology:WeeklyBoss ;
#     foaf:name "Dvalin" .
#
# genshinResource:Electro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Electro_Abyss_Mage" .
#
# genshinResource:Electro_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Vajrada_Amethyst_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Electro_Hypostasis" .
#
# genshinResource:Electro_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Electro_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Hydro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Electro_Slime" .
#
# genshinResource:Eula a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Eula"^^xsd:string ;
#     genshinOntology:birthday "2023-10-25T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Aphros_Delos ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Crystalline_Bloom ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     owl:sameAs wd:Q111079705 ;
#     foaf:name "Eula" .
#
# genshinResource:Eye_of_Perception a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Eye_of_Perception"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Catalyst ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Ring_of_Boreas ;
#     foaf:name "Eye_of_Perception" .
#
# genshinResource:Faruzan a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Faruzan"^^xsd:string ;
#     genshinOntology:birthday "2023-08-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Flosculi_Implexi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-12-07T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Light_Guiding_Tetrahedron ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Faruzan" .
#
# genshinResource:Fatui_Skirmisher a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Fatui_Skirmisher"^^xsd:string ;
#     genshinOntology:dropsMaterial <http://www.genshin.org/resource/Sergeant's_Insignia> ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Fatui_Skirmisher" .
#
# genshinResource:Favonius_Greatsword a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Favonius_Greatsword"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Claymore ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Favonius_Greatsword" .
#
# genshinResource:Favonius_Warbow a genshinOntology:Weapon,
#         owl:NamedIndividual ;
#     rdfs:label "Favonius_Warbow"^^xsd:string ;
#     genshinOntology:isWeaponType genshinOntology:Bow ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:usesWeaponUpgradeMaterial genshinResource:Basalt_Pillar ;
#     foaf:name "Favonius_Warbow" .
#
# genshinResource:Fischl a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Fischl"^^xsd:string ;
#     genshinOntology:birthday "2023-05-27T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Corvus ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     owl:sameAs wd:Q113499833 ;
#     foaf:name "Fischl" .
#
# genshinResource:Freminet a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Freminet"^^xsd:string ;
#     genshinOntology:birthday "2023-09-24T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "ATK"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Automaton ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-09-05T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Artificed_Spare_Clockwork_Component_-_Coppelius ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Freminet" .
#
# genshinResource:Furina a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Furina"^^xsd:string ;
#     genshinOntology:birthday "2023-10-13T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_Rate"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Animula_Choragi ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon true ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2023-11-08T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Fontaine ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Water_That_Failed_To_Transcend ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Furina" .
#
# genshinResource:Ganyu a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Ganyu"^^xsd:string ;
#     genshinOntology:birthday "2023-12-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Sinae_Unicornis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-01-12T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     owl:sameAs wd:Q107618618 ;
#     foaf:name "Ganyu" .
#
# genshinResource:Geo_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Geo_Abyss_Mage" .
#
# genshinResource:Geo_Hypostasis a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Hypostasis"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Prithiva_Topaz_Chunk ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Boss ;
#     foaf:name "Geo_Hypostasis" .
#
# genshinResource:Geo_Slime a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Geo_Slime"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Slime_Condensate ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Anemo ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Geo_Slime" .
#
# genshinResource:Gorou a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Gorou"^^xsd:string ;
#     genshinOntology:birthday "2023-05-18T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Geo ;
#     genshinOntology:hasAscensionPassive "Geo_DMG_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Canis_Bellatoris ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2021-12-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Bow ;
#     foaf:name "Gorou" .
#
# genshinResource:Hilichurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hilichurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Firm_Arrowhead ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Normal ;
#     foaf:name "Hilichurl" .
#
# genshinResource:Hu_Tao a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Hu_Tao"^^xsd:string ;
#     genshinOntology:birthday "2023-07-15T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Pyro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Papilio_Charontis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-03-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Juvenile_Jade ;
#     genshinOntology:usesWeaponType genshinOntology:Polearm ;
#     foaf:name "Hu_Tao" .
#
# genshinResource:Hydro_Abyss_Mage a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Abyss_Mage"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Ley_Line_Sprout ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Electro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Abyss_Mage" .
#
# genshinResource:Hydro_Samachurl a genshinOntology:Enemy,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro_Samachurl"^^xsd:string ;
#     genshinOntology:dropsMaterial genshinResource:Divining_Scroll ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:enemyWeakAgainst genshinResource:Pyro ;
#     genshinOntology:isEnemyType genshinOntology:Elite ;
#     foaf:name "Hydro_Samachurl" .
#
# genshinResource:Jean a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Jean"^^xsd:string ;
#     genshinOntology:birthday "2023-03-14T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Healing_Bonus"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Leo_Minor ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Healer ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hurricane_Seed ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Jean" .
#
# genshinResource:Kaedehara_Kazuha a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaedehara_Kazuha"^^xsd:string ;
#     genshinOntology:birthday "2023-10-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Anemo ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Acer_Palmatum ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-06-29T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Marionette_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     owl:sameAs wd:Q111684393 ;
#     foaf:name "Kaedehara_Kazuha" .
#
# genshinResource:Kaeya a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaeya"^^xsd:string ;
#     genshinOntology:birthday "2023-11-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "Energy_Recharge"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Pavo_Ocellus ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Mondstadt ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Hoarfrost_Core ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kaeya" .
#
# genshinResource:Kamisato_Ayaka a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayaka"^^xsd:string ;
#     genshinOntology:birthday "2023-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Cryo ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Grus_Nivis ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2021-07-21T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Perpetual_Heart ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     owl:sameAs wd:Q107618679 ;
#     foaf:name "Kamisato_Ayaka" .
#
# genshinResource:Kamisato_Ayato a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kamisato_Ayato"^^xsd:string ;
#     genshinOntology:birthday "2023-03-26T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Hydro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Cypressus_Custos ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter true ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2022-04-30T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Inazuma ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Dew_of_Repudation ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     foaf:name "Kamisato_Ayato" .
#
# genshinResource:Kaveh a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kaveh"^^xsd:string ;
#     genshinOntology:birthday "2023-07-09T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Dendro ;
#     genshinOntology:hasAscensionPassive "Elemental_Mastery"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Paradisaea ;
#     genshinOntology:hasGender "Male"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:Support ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 4 ;
#     genshinOntology:releaseDate "2023-05-02T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Sumeru ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Quelled_Creeper ;
#     genshinOntology:usesWeaponType genshinOntology:Claymore ;
#     foaf:name "Kaveh" .
#
# genshinResource:Keqing a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Keqing"^^xsd:string ;
#     genshinOntology:birthday "2023-11-20T00:00:00"^^xsd:dateTime ;
#     genshinOntology:elementAlignment genshinResource:Electro ;
#     genshinOntology:hasAscensionPassive "CRIT_DMG"^^xsd:string ;
#     genshinOntology:hasConstellation genshinResource:Trulla_Cementarii ;
#     genshinOntology:hasGender "Female"^^xsd:string ;
#     genshinOntology:hasRole genshinOntology:DPS ;
#     genshinOntology:isArchon false ;
#     genshinOntology:isLimitedCharacter false ;
#     genshinOntology:rarity 5 ;
#     genshinOntology:releaseDate "2020-09-28T00:00:00"^^xsd:dateTime ;
#     genshinOntology:residesAt genshinResource:Liyue ;
#     genshinOntology:usesCharacterUpgradeMaterial genshinResource:Lightning_Prism ;
#     genshinOntology:usesWeaponType genshinOntology:Sword ;
#     owl:sameAs wd:Q107287676 ;
#     foaf:name "Keqing" .
#
# genshinResource:Kirara a genshinOntology:Character,
#         owl:NamedIndividual ;
#     rdfs:label "Kirara"^^xsd:string ;
#     genshinOntology:birthday "2023-01-22T00:00:00"^^xsd:dateTime ;
# ...
#     rdfs:range genshinOntology:Element .
#
# genshinResource:Basalt_Pillar a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Basalt_Pillar"^^xsd:string ;
#     foaf:name "Basalt_Pillar" .
#
# genshinResource:Lightning_Prism a genshinOntology:Material,
#         owl:NamedIndividual ;
#     rdfs:label "Lightning_Prism"^^xsd:string .
#
# genshinOntology:Shielder a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Shielder"^^xsd:string ;
#     rdfs:comment "Prioritizes in shielding the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Shielder ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# :a a swrl:Variable .
#
# :b a swrl:Variable .
#
# genshinOntology:Normal a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Normal ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Dendro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Dendro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Hyperbloom,
#         genshinResource:Quicken .
#
# genshinOntology:Element a owl:Class ;
#     rdfs:comment "Enumerated Class. This is because there are only 7 elements in the game and it's been heavily implied throughout the story that there will only be 7" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:oneOf ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) ] .
#
# genshinOntology:Healer a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Healer"^^xsd:string ;
#     rdfs:comment "Prioritizes in healing the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Healer ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinResource:Geo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Geo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize .
#
# genshinOntology:Elite a genshinOntology:EnemyType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:subClassOf genshinOntology:Enemy ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Enemy [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Elite ;
#                         owl:onProperty genshinOntology:isEnemyType ] ) ] .
#
# genshinResource:Hydro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Hydro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Frozen,
#         genshinResource:Hyperbloom,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:Claymore a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any claymore in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Claymore ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinOntology:Polearm a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any polearm in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Polearm ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Pyro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Pyro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Burgeon,
#         genshinResource:Burning,
#         genshinResource:Crystallize,
#         genshinResource:Melt,
#         genshinResource:Overloaded,
#         genshinResource:Swirl,
#         genshinResource:Vaporize .
#
# genshinOntology:Bow a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any bow in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Bow ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Electro a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Electro"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Electro-Charged,
#         genshinResource:Hyperbloom,
#         genshinResource:Overloaded,
#         genshinResource:Quicken,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Support a genshinOntology:Role,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:label "Support"^^xsd:string ;
#     rdfs:comment "Prioritizes in giving buffs and removing debuffs from the team" ;
#     rdfs:subClassOf genshinOntology:PlayableCharacter ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:PlayableCharacter [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Support ;
#                         owl:onProperty genshinOntology:hasRole ] ) ] .
#
# genshinOntology:Catalyst a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any catalyst in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Catalyst ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Cryo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Cryo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Crystallize,
#         genshinResource:Frozen,
#         genshinResource:Melt,
#         genshinResource:Superconduct,
#         genshinResource:Swirl .
#
# genshinOntology:Sword a genshinOntology:WeaponType,
#         owl:Class,
#         owl:NamedIndividual ;
#     rdfs:comment "Represents any sword in the game" ;
#     rdfs:subClassOf genshinOntology:Weapon ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( genshinOntology:Weapon [ a owl:Restriction ;
#                         owl:hasValue genshinOntology:Sword ;
#                         owl:onProperty genshinOntology:isWeaponType ] ) ] .
#
# genshinResource:Anemo a genshinOntology:Element,
#         owl:NamedIndividual ;
#     rdfs:label "Anemo"^^xsd:string ;
#     genshinOntology:causesReaction genshinResource:Swirl .
#
# genshinOntology:DPS a genshinOntology:Role,
#         owl:NamedIndividual ;
#     rdfs:label "DPS"^^xsd:string .
#
# genshinOntology:Weapon a owl:Class ;
#     rdfs:comment "Weapons weilded by characters" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) ] .
#
# genshinOntology:Enemy a owl:Class ;
#     rdfs:comment "Enemies you fight throughout the world while adventuring" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:Boss genshinOntology:Elite genshinOntology:Normal genshinOntology:WeeklyBoss ) ] .
#
# genshinOntology:Material a owl:Class ;
#     rdfs:comment "Materials are resources dropped by enemies. Used to level characters or weapons" ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:unionOf ( genshinOntology:CharacterUpgradeMaterial genshinOntology:OtherMaterial genshinOntology:WeaponUpgradeMaterial ) ] .
#
# genshinOntology:Constellation a owl:Class ;
#     rdfs:comment "Constellations are a star pattern in the sky. Each character has their own unique constellation in this game." .
#
# genshinOntology:Character a owl:Class .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a swrl:Imp ;
#     rdfs:label "CharacterCanDefeatEnemy" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "Combination of characters and enemies where the character can easily defeat the enemy if the enemy is weak to the respective character's element" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :enemy ;
#                     swrl:argument2 :element ;
#                     swrl:propertyPredicate genshinOntology:enemyWeakAgainst ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:IndividualPropertyAtom ;
#                             swrl:argument1 :character ;
#                             swrl:argument2 :element ;
#                             swrl:propertyPredicate genshinOntology:elementAlignment ] ;
#                     rdf:rest [ a swrl:AtomList ;
#                             rdf:first [ a swrl:ClassAtom ;
#                                     swrl:argument1 :enemy ;
#                                     swrl:classPredicate genshinOntology:Enemy ] ;
#                             rdf:rest [ a swrl:AtomList ;
#                                     rdf:first [ a swrl:ClassAtom ;
#                                             swrl:argument1 :character ;
#                                             swrl:classPredicate genshinOntology:Character ] ;
#                                     rdf:rest () ] ] ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :character ;
#                     swrl:argument2 :enemy ;
#                     swrl:propertyPredicate genshinOntology:canEasilyDefeat ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinResource:Anemo genshinResource:Cryo genshinResource:Dendro genshinResource:Electro genshinResource:Geo genshinResource:Hydro genshinResource:Pyro ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:AnemoCharacter genshinOntology:CryoCharacter genshinOntology:DendroCharacter genshinOntology:ElectroCharacter genshinOntology:GeoCharacter genshinOntology:HydroCharacter genshinOntology:PyroCharacter ) .
#
# [] a swrl:Imp ;
#     rdfs:label "BowUser" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Bow ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:BowUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "ClaymoreInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:ClaymoreUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Claymore ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a swrl:Imp ;
#     rdfs:label "CatalystInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:CatalystUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Catalyst ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:Character genshinOntology:Constellation genshinOntology:Element genshinOntology:Enemy genshinOntology:EnemyType genshinOntology:Material genshinOntology:Reaction genshinOntology:Region genshinOntology:Role genshinOntology:Weapon genshinOntology:WeaponType ) .
#
# [] a swrl:Imp ;
#     rdfs:label "SwordInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :b ;
#                     swrl:classPredicate genshinOntology:Sword ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :a ;
#                             swrl:classPredicate genshinOntology:SwordUser ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .
#
# [] a owl:AllDifferent ;
#     owl:distinctMembers ( genshinOntology:Bow genshinOntology:Catalyst genshinOntology:Claymore genshinOntology:Polearm genshinOntology:Sword ) .
#
# [] a owl:AllDisjointClasses ;
#     owl:members ( genshinOntology:BowUser genshinOntology:CatalystUser genshinOntology:ClaymoreUser genshinOntology:PolearmUser genshinOntology:SwordUser ) .
#
# [] a swrl:Imp ;
#     rdfs:label "PolearmInference" ;
#     swrla:isRuleEnabled true ;
#     rdfs:comment "" ;
#     swrl:body [ a swrl:AtomList ;
#             rdf:first [ a swrl:ClassAtom ;
#                     swrl:argument1 :a ;
#                     swrl:classPredicate genshinOntology:PolearmUser ] ;
#             rdf:rest [ a swrl:AtomList ;
#                     rdf:first [ a swrl:ClassAtom ;
#                             swrl:argument1 :b ;
#                             swrl:classPredicate genshinOntology:Polearm ] ;
#                     rdf:rest () ] ] ;
#     swrl:head [ a swrl:AtomList ;
#             rdf:first [ a swrl:IndividualPropertyAtom ;
#                     swrl:argument1 :a ;
#                     swrl:argument2 :b ;
#                     swrl:propertyPredicate genshinOntology:canWeildWeapon ] ;
#             rdf:rest () ] .

# %%
g.serialize(destination="afterLinking.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Final Save

# %%
g.serialize(destination="afterAddingEverything.rdf", format="application/rdf+xml")
# Out:
# <Graph identifier=Nf1cc6f9c6da0490896c863e1456403dc (<class 'rdflib.graph.Graph'>)>
